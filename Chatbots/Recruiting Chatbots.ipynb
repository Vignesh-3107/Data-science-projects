# %% [markdown]
# ## Recruiting Chatbots
#
# ### Author: Vignesh C

# %%
jobs_list={1:"Driver",2:"Cook",3:"Maid",4:"Delivery Person",5:"Repair Person"}
wages_list={1:"15K-20K",2:"20K-25K",3:"25K-30K",4:"30K-35K"}
driver_role={1:{"role":"OLA Driver","Wage":"17K per month"},2:{"role":"UBER Driver","Wage":"17K per month"},3:{"role":"Personal Driver","Wage":"15K per month"},4:{"role":"Private Driver","Wage":"10K per month"}}
print(" Hello and welcome to Awesome Jobs.\n We will together find a better job for you.")

def get_name(name):
    if " " in name:
        get_details()
    else:
        retry()
def retry():
    print(" Please give full name. e.g.. Isaac Newton")
    name=input()
    get_name(name)
def get_details():
    print(" Which city are you from?")
    city=input()
    print(" Great. What's your gender?")
    gender=input()
    print(" How old are you?")
    age=input()
    print(" This is exciting.\n I already have found more than 300 jobs that you might like.\n What kind of jobs do you like? select upto 3 categories \n Press enter when you are done")
    for i in jobs_list.items():
        print(i)
    job=int(input())
    if job!==1:
        print("NO VACANCY CURRENTLY NOW ")
        
    print(" How much monthly salary do you expect?")
    for i in wages_list.items():
        print(i)
    wages=int(input())
    print(" Great. Here’s a list of great jobs you might like.\n If you like them, select one to apply for it.")
    for i in driver_role.keys():
        print(str(i)+'--')
        for j in driver_role[i].values():
            print(" \t "+j,end=" \t")
        print()
    job_role=int(input())
    print(" Your application has been successfully sent to Employer_name.\n Data Retrieval API Integration for Employer specific Screening Questions.")
    confirm=input("Press Enter for Confirm")
    print(" You’ve picked Employer_name! Great choice.\n The next step is to schedule your interview with them.\n Data Retrieval API Integration for Employer specific Screening Questions.")
    confirm=input("Press Enter for Confirm")
    print(" It was great talking to you.\n The exployer will contact you to get more information about your job application")
    
print(" Tell me, what is your full name?")
name=input()
get_name(name)
# Out:
#  Hello and welcome to Awesome Jobs.
#  We will together find a better job for you.
#  Tell me, what is your full name?
# gh
#  Please give full name. e.g.. Isaac Newton
# ty hnk
#  Which city are you from?
# covai
#  Great. What's your gender?
# male
#  How old are you?
# 13
#  This is exciting.
#  I already have found more than 300 jobs that you might like.
#  What kind of jobs do you like? select upto 3 categories
#  Press enter when you are done
# (1, 'Driver')
# (2, 'Cook')
# (3, 'Maid')
# (4, 'Delivery Person')
# (5, 'Repair Person')
# 1
#  How much monthly salary do you expect?
# (1, '15K-20K')
# (2, '20K-25K')
# (3, '25K-30K')
# (4, '30K-35K')
# 2
#  Great. Here’s a list of great jobs you might like.
#  If you like them, select one to apply for it.
# 1--
#  	 OLA Driver 	 	 17K per month
# 2--
#  	 UBER Driver 	 	 17K per month
# 3--
#  	 Personal Driver 	 	 15K per month
# 4--
#  	 Private Driver 	 	 10K per month
# 2
# ...
